# %%
import pandas as pd
from scipy.stats import shapiro
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

model_names = ["meta-llama_Llama-3.2-3B", "facebook_xglm-4.5B", "THUDM_chatglm3-6b-base", "TsinghuaAI_CPM-Generate"]

# %%
filename = f'result/2_{model_names[0]}_results_apx.csv'
df = pd.read_csv(filename, on_bad_lines='warn')

# Columns to test
apx_columns = ['apx_1', 'apx_2', 'apx_3']

# Run normality test and visualization for each APX column
for col in apx_columns:
    print(f"\n=== Shapiro-Wilk Test for {col} ===")

    # Clean data: remove NaNs and inf values
    data = df[col].replace([float('inf'), -float('inf')], pd.NA).dropna()

    # Shapiro-Wilk test
    stat, p = shapiro(data)
    print(f"Statistic = {stat:.4f}, p-value = {p:.4e}")
    if p > 0.05:
        print("✅ Data appears normally distributed.")
    else:
        print("❌ Data does not appear normally distributed.")

    # Plot histogram with KDE
    plt.figure(figsize=(6, 4))
    sns.histplot(data, kde=True, bins=30)
    plt.title(f"Histogram of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.tight_layout()
    plt.show()

    # Q-Q Plot
    plt.figure(figsize=(6, 4))
    stats.probplot(data, dist="norm", plot=plt)
    plt.title(f"Q-Q Plot of {col}")
    plt.tight_layout()
    plt.show()
# Out:
# === Shapiro-Wilk Test for apx_1 ===
# Statistic = 0.2124, p-value = 2.3114e-135
# ❌ Data does not appear normally distributed.
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:573: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 24882.
#   res = hypotest_fun_out(*samples, **kwds)
# === Shapiro-Wilk Test for apx_2 ===
# Statistic = 0.3994, p-value = 1.6809e-127
# ❌ Data does not appear normally distributed.
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:573: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 24882.
#   res = hypotest_fun_out(*samples, **kwds)
# === Shapiro-Wilk Test for apx_3 ===
# Statistic = 0.2386, p-value = 2.2802e-134
# ❌ Data does not appear normally distributed.
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:573: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 24882.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
filename = f'result/2_{model_names[1]}_results_apx.csv'
df = pd.read_csv(filename, on_bad_lines='warn')

# Columns to test
apx_columns = ['apx_1', 'apx_2', 'apx_3']

# Run normality test and visualization for each APX column
for col in apx_columns:
    print(f"\n=== Shapiro-Wilk Test for {col} ===")

    # Clean data: remove NaNs and inf values
    data = df[col].replace([float('inf'), -float('inf')], pd.NA).dropna()

    # Shapiro-Wilk test
    stat, p = shapiro(data)
    print(f"Statistic = {stat:.4f}, p-value = {p:.4e}")
    if p > 0.05:
        print("✅ Data appears normally distributed.")
    else:
        print("❌ Data does not appear normally distributed.")

    # Plot histogram with KDE
    plt.figure(figsize=(6, 4))
    sns.histplot(data, kde=True, bins=30)
    plt.title(f"Histogram of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.tight_layout()
    plt.show()

    # Q-Q Plot
    plt.figure(figsize=(6, 4))
    stats.probplot(data, dist="norm", plot=plt)
    plt.title(f"Q-Q Plot of {col}")
    plt.tight_layout()
    plt.show()
# Out:
# === Shapiro-Wilk Test for apx_1 ===
# Statistic = 0.0646, p-value = 1.7942e-140
# ❌ Data does not appear normally distributed.
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:573: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 24882.
#   res = hypotest_fun_out(*samples, **kwds)
# === Shapiro-Wilk Test for apx_2 ===
# Statistic = 0.4355, p-value = 9.8383e-126
# ❌ Data does not appear normally distributed.
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:573: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 24882.
#   res = hypotest_fun_out(*samples, **kwds)
# === Shapiro-Wilk Test for apx_3 ===
# Statistic = 0.6013, p-value = 4.5289e-116
# ❌ Data does not appear normally distributed.
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:573: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 24882.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
filename = f'result/2_{model_names[2]}_results_apx.csv'
df = pd.read_csv(filename, on_bad_lines='warn')

# Columns to test
apx_columns = ['apx_1', 'apx_2', 'apx_3']

# Run normality test and visualization for each APX column
for col in apx_columns:
    print(f"\n=== Shapiro-Wilk Test for {col} ===")

    # Clean data: remove NaNs and inf values
    data = df[col].replace([float('inf'), -float('inf')], pd.NA).dropna()

    # Shapiro-Wilk test
    stat, p = shapiro(data)
    print(f"Statistic = {stat:.4f}, p-value = {p:.4e}")
    if p > 0.05:
        print("✅ Data appears normally distributed.")
    else:
        print("❌ Data does not appear normally distributed.")

    # Plot histogram with KDE
    plt.figure(figsize=(6, 4))
    sns.histplot(data, kde=True, bins=30)
    plt.title(f"Histogram of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.tight_layout()
    plt.show()

    # Q-Q Plot
    plt.figure(figsize=(6, 4))
    stats.probplot(data, dist="norm", plot=plt)
    plt.title(f"Q-Q Plot of {col}")
    plt.tight_layout()
    plt.show()
# Out:
# === Shapiro-Wilk Test for apx_1 ===
# Statistic = 0.6435, p-value = 4.8061e-113
# ❌ Data does not appear normally distributed.
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:573: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 24882.
#   res = hypotest_fun_out(*samples, **kwds)
# === Shapiro-Wilk Test for apx_2 ===
# Statistic = 0.6230, p-value = 1.5045e-114
# ❌ Data does not appear normally distributed.
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:573: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 24882.
#   res = hypotest_fun_out(*samples, **kwds)
# === Shapiro-Wilk Test for apx_3 ===
# Statistic = 0.4960, p-value = 1.5320e-122
# ❌ Data does not appear normally distributed.
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:573: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 24882.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
filename = f'result/2_{model_names[3]}_results_apx.csv'
df = pd.read_csv(filename, on_bad_lines='warn')

# Columns to test
apx_columns = ['apx_1', 'apx_2', 'apx_3']

# Run normality test and visualization for each APX column
for col in apx_columns:
    print(f"\n=== Shapiro-Wilk Test for {col} ===")

    # Clean data: remove NaNs and inf values
    data = df[col].replace([float('inf'), -float('inf')], pd.NA).dropna()

    # Shapiro-Wilk test
    stat, p = shapiro(data)
    print(f"Statistic = {stat:.4f}, p-value = {p:.4e}")
    if p > 0.05:
        print("✅ Data appears normally distributed.")
    else:
        print("❌ Data does not appear normally distributed.")

    # Plot histogram with KDE
    plt.figure(figsize=(6, 4))
    sns.histplot(data, kde=True, bins=30)
    plt.title(f"Histogram of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.tight_layout()
    plt.show()

    # Q-Q Plot
    plt.figure(figsize=(6, 4))
    stats.probplot(data, dist="norm", plot=plt)
    plt.title(f"Q-Q Plot of {col}")
    plt.tight_layout()
    plt.show()
# Out:
# === Shapiro-Wilk Test for apx_1 ===
# Statistic = 0.7416, p-value = 1.4688e-104
# ❌ Data does not appear normally distributed.
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:573: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 24882.
#   res = hypotest_fun_out(*samples, **kwds)
# === Shapiro-Wilk Test for apx_2 ===
# Statistic = 0.5238, p-value = 5.8703e-121
# ❌ Data does not appear normally distributed.
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:573: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 24882.
#   res = hypotest_fun_out(*samples, **kwds)
# === Shapiro-Wilk Test for apx_3 ===
# Statistic = 0.8417, p-value = 2.6998e-92
# ❌ Data does not appear normally distributed.
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:573: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 24882.
#   res = hypotest_fun_out(*samples, **kwds)
